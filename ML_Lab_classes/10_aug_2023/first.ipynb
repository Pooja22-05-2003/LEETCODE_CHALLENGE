# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from pandas import ExcelFile

# %%
# !pip install openpyxl
# Out:
# ...
#      -------------------------------------- 250.0/250.0 KB 1.9 MB/s eta 0:00:00
# ...
# WARNING: You are using pip version 22.0.4; however, version 23.2.1 is available.
# You should consider upgrading via the 'C:\Users\acer\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip' command.

# %%
file=pd.ExcelFile("D:/IGDTUW-D/College Years/3rd year/5th sem/ML_LAB/Dataset/10_aug_2023/BrazilCOVIDData.xlsx")

# %%
f1=pd.read_excel(file,"Brazil Covid-19 data")

# %%
# Q Q1. Is there any association between temperature COVID-19 transmission (response variable).
# Create a suitable visualization and explain.
f1.head()
# Out:
#    Region State Municipality  State-code  Municipality-code  \
# 0  Brasil   NaN          NaN          76                NaN
# 1  Brasil   NaN          NaN          76                NaN
# 2  Brasil   NaN          NaN          76                NaN
# 3  Brasil   NaN          NaN          76                NaN
# 4  Brasil   NaN          NaN          76                NaN
#
#    Health-region-code Health-region-name       Date  Week #  \
# 0                 NaN                NaN 2020-02-25       9
# 1                 NaN                NaN 2020-02-26       9
# 2                 NaN                NaN 2020-02-27       9
# 3                 NaN                NaN 2020-02-28       9
# 4                 NaN                NaN 2020-02-29       9
#
#   Population as of 2019  Accumulated cases  New cases  Accumulated deaths  \
# 0             210147125                  0          0                   0
# 1             210147125                  1          1                   0
# ...

# %%
f1.sort_values(by=['State-code','Date'])
# Out:
#      Region State Municipality  State-code  Municipality-code  \
# 182   Norte    RO          NaN          11                NaN
# 183   Norte    RO          NaN          11                NaN
# 184   Norte    RO          NaN          11                NaN
# 185   Norte    RO          NaN          11                NaN
# 186   Norte    RO          NaN          11                NaN
# ..      ...   ...          ...         ...                ...
# 177  Brasil   NaN          NaN          76                NaN
# 178  Brasil   NaN          NaN          76                NaN
# 179  Brasil   NaN          NaN          76                NaN
# 180  Brasil   NaN          NaN          76                NaN
# 181  Brasil   NaN          NaN          76                NaN
#
#      Health-region-code Health-region-name       Date  Week #  \
# 182                 NaN                NaN 2020-02-25       9
# 183                 NaN                NaN 2020-02-26       9
# ...
